# %%
import ziafont as zf
zf.config.debug = True
zf.__version__
# Out:
# '0.5-alpha'

# %%
font = zf.Font('../docs/NotoSerif-Regular.ttf')

# %%
font.info.names
# Out:
# FontNames(copyright='Copyright 2012 Google Inc. All Rights Reserved.', family='Noto Serif', subfamily='Regular', unique='Monotype Imaging - Noto Serif', name='Noto Serif', nameversion='Version 1.02', postscript='NotoSerif', trademark='Noto is a trademark of Google Inc. and may be registered in certain jurisdictions.', manufacturer='Monotype Imaging Inc.', designer='Monotype Design team', description='Designed by Monotype design team', vendorurl='http://code.google.com/p/noto/', designerurl='http://www.monotypeimaging.com/ProductsServices/TypeDesignerShowcase', license='Licensed under the Apache License, Version 2.0', LicenseURL='http://www.apache.org/licenses/LICENSE-2.0')

# %%
font.glyph('a')

# %%
font.glyph('G').test()

# %%
font.glyph('Ñ')

# %%
font.glyph('ǟ')

# %%
font.glyph('⍣')  # Unknown glyph

# %%
font.text('VALVES', kern=True)

# %%
font.text('VALVES', kern=False)

# %%
font.text('Hello\nWorld', size=22)

# %%
font.text('Hello\nWorld', size=22, halign='center')

# %%
font.text('Hello\nWorld', size=22, halign='right')

# %%
import xml.etree.ElementTree as ET
from IPython.display import SVG

# %%
# Adding to existing SVG
svg = ET.Element('svg')
svg.attrib['width'] = '200'
svg.attrib['height'] = '220'
svg.attrib['xmlns'] = 'http://www.w3.org/2000/svg'
svg.attrib['viewBox'] = f'0 0 200 220'

font.text('ABCD\n123', size=18, halign='right', valign='base').drawon(svg, 50, 20)
font.text('ABCD\n123', size=18, halign='center', valign='base').drawon(svg, 100, 20)
font.text('ABCD\n123', size=18, halign='left', valign='base').drawon(svg, 150, 20)

font.text('ABCD\n123', size=18, halign='right', valign='center').drawon(svg, 50, 80)
font.text('ABCD\n123', size=18, halign='center', valign='center').drawon(svg, 100, 80)
font.text('ABCD\n123', size=18, halign='left', valign='center').drawon(svg, 150, 80)

font.text('ABCD\n123', size=18, halign='right', valign='top').drawon(svg, 50, 110)
font.text('ABCD\n123', size=18, halign='center', valign='top').drawon(svg, 100, 110)
font.text('ABCD\n123', size=18, halign='left', valign='top').drawon(svg, 150, 110)

font.text('ABCD\n123', size=18, halign='right', valign='bottom').drawon(svg, 50, 210)
font.text('ABCD\n123', size=18, halign='center', valign='bottom').drawon(svg, 100, 210)
font.text('ABCD\n123', size=18, halign='left', valign='bottom').drawon(svg, 150, 210)

SVG(ET.tostring(svg))

# %%
assert 'symbol' in font.glyph('a').svg()

# %%
# SVG 1.x mode
zf.config.svg2 = False

svg = ET.Element('svg')
svg.attrib['width'] = '200'
svg.attrib['height'] = '220'
svg.attrib['xmlns'] = 'http://www.w3.org/2000/svg'
svg.attrib['viewBox'] = f'0 0 200 220'

font.text('ABCD\n123', size=18, halign='right', valign='base').drawon(svg, 50, 20)
font.text('ABCD\n123', size=18, halign='center', valign='base').drawon(svg, 100, 20)
font.text('ABCD\n123', size=18, halign='left', valign='base').drawon(svg, 150, 20)

font.text('ABCD\n123', size=18, halign='right', valign='center').drawon(svg, 50, 80)
font.text('ABCD\n123', size=18, halign='center', valign='center').drawon(svg, 100, 80)
font.text('ABCD\n123', size=18, halign='left', valign='center').drawon(svg, 150, 80)

font.text('ABCD\n123', size=18, halign='right', valign='top').drawon(svg, 50, 110)
font.text('ABCD\n123', size=18, halign='center', valign='top').drawon(svg, 100, 110)
font.text('ABCD\n123', size=18, halign='left', valign='top').drawon(svg, 150, 110)

font.text('ABCD\n123', size=18, halign='right', valign='bottom').drawon(svg, 50, 210)
font.text('ABCD\n123', size=18, halign='center', valign='bottom').drawon(svg, 100, 210)
font.text('ABCD\n123', size=18, halign='left', valign='bottom').drawon(svg, 150, 210)

assert 'symbol' not in ET.tostring(svg, encoding='unicode')
SVG(ET.tostring(svg))

# %%
# Text class, using default font
# Make sure J descender is fully enclosed in bounding box
zf.Text('ABC DEF\nGHI JKL')

# %%
zf.Text('ABC DEF\nGHI JKL', halign='center')

# %%
zf.Text('ABC DEF\nGHI JKL', halign='right')

# %%
zf.config.precision = 5
font.text('P', size=160).svg()
# Out:
# '<svg xmlns="http://www.w3.org/2000/svg" width="96.64062" height="217.89062" viewBox="0 -171.01562 96.64062 217.89062"><g word="P" transform=""><path d="M 6.09375 0 L 6.09375 0 L 6.09375 -6.71875 L 8.125 -6.71875 Q 10.85938 -6.71875 13.24219 -7.10938 Q 15.625 -7.5 17.42188 -8.71094 Q 19.21875 -9.92188 20.23438 -12.1875 Q 21.25 -14.45312 21.25 -18.20312 L 21.25 -96.64062 Q 21.25 -100.15625 20.19531 -102.30469 Q 19.14062 -104.45312 17.34375 -105.625 Q 15.54688 -106.79688 13.16406 -107.14844 Q 10.78125 -107.5 8.125 -107.5 L 6.09375 -107.5 L 6.09375 -114.21875 L 51.01562 -114.21875 Q 61.09375 -114.21875 68.51562 -111.91406 Q 75.9375 -109.60938 80.78125 -105.27344 Q 85.625 -100.9375 88.00781 -94.76562 Q 90.39062 -88.59375 90.39062 -80.78125 Q 90.39062 -73.67188 88.16406 -67.10938 Q 85.9375 -60.54688 80.85938 -55.50781 Q 75.78125 -50.46875 67.57812 -47.46094 Q 59.375 -44.45312 47.5 -44.45312 L 37.42188 -44.45312 L 37.42188 -17.42188 Q 37.42188 -13.90625 38.47656 -11.75781 Q 39.53125 -9.60938 41.32812 -8.51562 Q 43.125 -7.42188 45.50781 -7.07031 Q 47.89062 -6.71875 50.54688 -6.71875 L 55.85938 -6.71875 L 55.85938 0 M 37.42188 -52.03125 L 37.42188 -52.03125 L 45.9375 -52.03125 Q 53.20312 -52.03125 58.35938 -53.55469 Q 63.51562 -55.07812 66.79688 -58.47656 Q 70.07812 -61.875 71.60156 -67.22656 Q 73.125 -72.57812 73.125 -80.15625 Q 73.125 -86.875 71.79688 -91.83594 Q 70.46875 -96.79688 67.5 -100.07812 Q 64.53125 -103.35938 59.80469 -104.96094 Q 55.07812 -106.5625 48.28125 -106.5625 L 37.42188 -106.5625 Z " /><rect x="0" y="-171.01562" width="96.64062" height="217.89062" fill="none" stroke="red" /><circle cx="0" cy="0" r="3" fill="red" stroke="red" /></g><rect x="0" y="-171.01562" width="96.64062" height="217.89062" fill="none" stroke="blue" /></svg>'

# %%
zf.config.precision = 1
font.text('P', size=160).svg()
# Out:
# '<svg xmlns="http://www.w3.org/2000/svg" width="96.6" height="217.9" viewBox="0 -171 96.6 217.9"><g word="P" transform=""><path d="M 6.1 0 L 6.1 0 L 6.1 -6.7 L 8.1 -6.7 Q 10.9 -6.7 13.2 -7.1 Q 15.6 -7.5 17.4 -8.7 Q 19.2 -9.9 20.2 -12.2 Q 21.2 -14.5 21.2 -18.2 L 21.2 -96.6 Q 21.2 -100.2 20.2 -102.3 Q 19.1 -104.5 17.3 -105.6 Q 15.5 -106.8 13.2 -107.1 Q 10.8 -107.5 8.1 -107.5 L 6.1 -107.5 L 6.1 -114.2 L 51 -114.2 Q 61.1 -114.2 68.5 -111.9 Q 75.9 -109.6 80.8 -105.3 Q 85.6 -100.9 88 -94.8 Q 90.4 -88.6 90.4 -80.8 Q 90.4 -73.7 88.2 -67.1 Q 85.9 -60.5 80.9 -55.5 Q 75.8 -50.5 67.6 -47.5 Q 59.4 -44.5 47.5 -44.5 L 37.4 -44.5 L 37.4 -17.4 Q 37.4 -13.9 38.5 -11.8 Q 39.5 -9.6 41.3 -8.5 Q 43.1 -7.4 45.5 -7.1 Q 47.9 -6.7 50.5 -6.7 L 55.9 -6.7 L 55.9 0 M 37.4 -52 L 37.4 -52 L 45.9 -52 Q 53.2 -52 58.4 -53.6 Q 63.5 -55.1 66.8 -58.5 Q 70.1 -61.9 71.6 -67.2 Q 73.1 -72.6 73.1 -80.2 Q 73.1 -86.9 71.8 -91.8 Q 70.5 -96.8 67.5 -100.1 Q 64.5 -103.4 59.8 -105 Q 55.1 -106.6 48.3 -106.6 L 37.4 -106.6 Z " /><rect x="0" y="-171" width="96.6" height="217.9" fill="none" stroke="red" /><circle cx="0" cy="0" r="3" fill="red" stroke="red" /></g><rect x="0" y="-171" width="96.6" height="217.9" fill="none" stroke="blue" /></svg>'

# %%
zf.Text('Orange', font=font, color='orange')

# %%
font.text('P', size=40, color='pink')

# %%
font.text('Rotated', rotation=10,
          valign='bottom', halign='left',
          rotation_mode='default')

# %%
font.text('Rotated', rotation=110,
          valign='center', halign='right',
          rotation_mode='center')

# %%
# Rotations - default mode
# (See https://matplotlib.org/stable/gallery/text_labels_and_annotations/demo_text_rotation_mode.html)
svg = ET.Element('svg')
svg.attrib['xmlns'] = 'http://www.w3.org/2000/svg'
svg.attrib['xmlns:xlink'] = 'http://www.w3.org/1999/xlink'
svg.attrib['width'] = '500'
svg.attrib['height'] = '300'
svg.attrib['viewBox'] = '0 0 500 300'

for xy, halign, valign in [((20, 20), 'left', 'top'),
                           ((100, 20), 'center', 'top'),
                           ((180, 20), 'right', 'top'),
                           ((20, 80), 'left', 'center'),
                           ((100, 80), 'center', 'center'),
                           ((180, 80), 'right', 'center'),
                           ((20, 130), 'left', 'base'),
                           ((100, 120), 'center', 'base'),
                           ((180, 110), 'right', 'base'),
                           ((20, 180), 'left', 'bottom'),
                           ((100, 180), 'center', 'bottom'),
                           ((180, 180), 'right', 'bottom'),

                          ]:
    circ = ET.SubElement(svg, 'circle')
    circ.set('cx', str(xy[0]))
    circ.set('cy', str(xy[1]))
    circ.set('r', '3')
    circ.set('stroke', 'blue')
    circ.set('fill', 'blue')

    font.text('Hello\n123', rotation=30,
                 size=12,
                 rotation_mode = 'default',
                 halign=halign, valign=valign).drawon(svg, xy[0], xy[1])

SVG(ET.tostring(svg))

# %%
# Rotations - anchor mode
# (See https://matplotlib.org/stable/gallery/text_labels_and_annotations/demo_text_rotation_mode.html)
svg = ET.Element('svg')
svg.attrib['xmlns'] = 'http://www.w3.org/2000/svg'
svg.attrib['xmlns:xlink'] = 'http://www.w3.org/1999/xlink'
svg.attrib['width'] = '500'
svg.attrib['height'] = '300'
svg.attrib['viewBox'] = '0 0 500 300'

for xy, halign, valign in [((20, 20), 'left', 'top'),
                           ((100, 20), 'center', 'top'),
                           ((180, 20), 'right', 'top'),
                           ((20, 80), 'left', 'center'),
                           ((100, 80), 'center', 'center'),
                           ((180, 80), 'right', 'center'),
                           ((20, 130), 'left', 'base'),
                           ((100, 120), 'center', 'base'),
                           ((180, 120), 'right', 'base'),
                           ((20, 180), 'left', 'bottom'),
                           ((100, 180), 'center', 'bottom'),
                           ((180, 180), 'right', 'bottom'),

                          ]:
    circ = ET.SubElement(svg, 'circle')
    circ.set('cx', str(xy[0]))
    circ.set('cy', str(xy[1]))
    circ.set('r', '4')
    circ.set('stroke', 'blue')
    circ.set('fill', 'blue')

    font.text('Hello\n123', rotation=30,
                 size=12,
                 rotation_mode = 'anchor',
                 halign=halign, valign=valign).drawon(svg, xy[0], xy[1])

SVG(ET.tostring(svg))

# %%
# Empty <path> elements should be removed
assert 'path' not in font.glyph(' ').svg()
assert 'path' not in font.text('   ').svg()

# %%
# Raise warning if font not found
try:
    font = zf.Font('unknownfont')
except FileNotFoundError:
    print('PASS')
else:
    raise
# Out:
# PASS
